# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('clocks/clock2.png',0)
edges = cv2.Canny(img,100,200)

plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image')
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image')
plt.show()

# %%
im2, contours, hierarchy = cv2.findContours(edges,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

# %%
img_draw_contour = cv2.drawContours(img, contours, -1, (0,0, 255), 1)
plt.imshow(img_draw_contour, cmap = 'gray')
plt.show()

# %%
areas = []
for contour in contours:
    x,y,w,h = cv2.boundingRect(contour)
    areas.append(w*h)
sorted(areas)
# Out:
# [1,
#  1,
#  1,
#  1,
#  2,
#  4,
#  4,
#  4,
#  4,
#  6,
#  6,
#  6,
#  9,
#  9,
#  9,
#  9,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  25,
#  27,
#  27,
#  30,
#  30,
#  30,
#  30,
#  42,
#  42,
#  48,
#  48,
#  48,
#  48,
#  48,
#  48,
#  48,
#  48,
#  48,
#  50,
#  51,
#  54,
#  54,
#  56,
#  60,
#  60,
#  64,
#  64,
#  77,
#  78,
#  81,
#  96,
#  96,
#  96,
#  102,
#  108,
#  112,
#  112,
#  112,
#  112,
#  112,
#  120,
#  126,
#  160,
#  168,
#  187,
#  204,
#  216,
#  216,
#  216,
#  216,
#  216,
#  216,
#  216,
#  216,
#  234,
#  234,
#  648,
#  8633,
#  15318,
#  40000,
#  40000,
#  43264,
#  43264]

# %%
import pickle
pickle.dump(contours, open('contours.pk', 'w'))
